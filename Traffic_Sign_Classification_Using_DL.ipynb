# %% [markdown]
# <a href="https://colab.research.google.com/github/FatmaElZahraaSamir/Traffic-Sign-Classification-Using-DL/blob/master/Traffic_Sign_Classification_Using_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1: PROJECT OVERVIEW

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/FatmaElZahraaSamir/Traffic-Sign-Classification-Using-DL/master/imgs/1.png)

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/FatmaElZahraaSamir/Traffic-Sign-Classification-Using-DL/master/imgs/2.png)

# %% [markdown]
# # 2: IMPORT LIBRARIES/DATASETS

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle
import random
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/FatmaElZahraaSamir/Traffic-Sign-Classification-Using-DL/master/imgs/3.png)

# %%
with open("/content/gdrive/My Drive/Colab Notebooks/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("/content/gdrive/My Drive/Colab Notebooks/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("/content/gdrive/My Drive/Colab Notebooks/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %% [markdown]
# # 3: PERFORM IMAGES VISUALIZATION

# %%
i = np.random.randint(1, len(X_train))
plt.imshow(X_train[i])
y_train[i]
# Out:
# 4

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 5
L_grid = 5

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations

fig, axes = plt.subplots(L_grid, W_grid, figsize = (10,10))

axes = axes.ravel() # flaten the 5 x 5 matrix into 25 array

n_training = len(X_train) # get the length of the training dataset

# Select a random number from 0 to n_training
# create evenly spaces variables 
for i in np.arange(0, W_grid * L_grid):
    # Select a random number
    index = np.random.randint(0, n_training)
    # read and display an image with the selected index    
    axes[i].imshow(X_train[index])
    axes[i].set_title(y_train[index], fontsize = 15)
    axes[i].axis('off')
    
plt.subplots_adjust(hspace = 0.4)

# %% [markdown]
# # 4: CONVERT IMAGES TO GRAYSCALE AND PERFORM NORMALIZATION

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train/3, axis = 3, keepdims = True)
X_test_gray = np.sum(X_test/3, axis = 3, keepdims = True)
X_validation_gray = np.sum(X_validation/3, axis = 3, keepdims = True)

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_train_gray_norm = (X_train_gray -128) / 128
X_test_gray_norm = (X_test_gray -128) / 128
X_validation_gray_norm = (X_validation_gray -128) / 128

# %%
X_train_gray_norm
# Out:
# array([[[[ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          ...,
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ]],
#
#         [[ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          ...,
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ]],
#
#         [[ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          ...,
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ]],
#
#         ...,
#
#         [[-0.6796875 ],
#          [-0.6796875 ],
#          [-0.67708333],
#          ...,
#          [-0.64322917],
#          [-0.63802083],
#          [-0.63541667]],
#
#         [[-0.68489583],
#          [-0.69010417],
#          [-0.69010417],
#          ...,
#          [-0.64322917],
#          [-0.63802083],
#          [-0.63802083]],
#
#         [[-0.69270833],
#          [-0.69270833],
#          [-0.69270833],
#          ...,
#          [-0.640625  ],
#          [-0.640625  ],
#          [-0.63541667]]],
#
#
#        [[[-0.36458333],
#          [-0.671875  ],
#          [-0.71614583],
#          ...,
#          [-0.38802083],
#          [-0.40885417],
#          [-0.45572917]],
#
#         [[ 0.0703125 ],
#          [-0.265625  ],
#          [-0.4609375 ],
#          ...,
#          [-0.33072917],
#          [-0.45572917],
#          [-0.46614583]],
#
#         [[ 0.0390625 ],
#          [-0.11979167],
#          [-0.30989583],
#          ...,
#          [-0.52604167],
#          [-0.57552083],
#          [-0.609375  ]],
#
#         ...,
#
#         [[-0.64583333],
#          [-0.66145833],
#          [-0.55729167],
#          ...,
#          [-0.15625   ],
#          [-0.14583333],
#          [-0.32552083]],
#
#         [[-0.6796875 ],
#          [-0.68229167],
#          [-0.60677083],
#          ...,
#          [-0.16666667],
#          [-0.22916667],
#          [-0.27604167]],
#
#         [[-0.73697917],
#          [-0.73177083],
#          [-0.53125   ],
#          ...,
#          [-0.34114583],
#          [-0.4375    ],
#          [-0.34114583]]],
#
#
#        [[[ 0.29166667],
#          [ 0.35416667],
#          [ 0.13020833],
#          ...,
#          [-0.53125   ],
#          [-0.57552083],
#          [-0.54427083]],
#
#         [[ 0.31770833],
#          [ 0.44791667],
#          [ 0.3359375 ],
#          ...,
#          [-0.5390625 ],
#          [-0.4140625 ],
#          [-0.24739583]],
#
#         [[ 0.32552083],
#          [ 0.5234375 ],
#          [ 0.45572917],
#          ...,
#          [-0.21875   ],
#          [ 0.015625  ],
#          [ 0.18229167]],
#
#         ...,
#
#         [[-0.15885417],
#          [-0.5       ],
#          [-0.546875  ],
#          ...,
#          [ 0.68229167],
#          [ 0.5390625 ],
#          [ 0.43489583]],
#
#         [[-0.13541667],
#          [-0.44270833],
#          [-0.46614583],
#          ...,
#          [ 0.5703125 ],
#          [ 0.54427083],
#          [ 0.55729167]],
#
#         [[-0.1015625 ],
#          [-0.38541667],
#          [-0.40625   ],
#          ...,
#          [ 0.58072917],
#          [ 0.60677083],
#          [ 0.60677083]]],
#
#
#        ...,
#
#
#        [[[ 0.1875    ],
#          [ 0.69791667],
#          [ 0.859375  ],
#          ...,
#          [ 0.08854167],
#          [-0.10677083],
#          [ 0.359375  ]],
#
#         [[ 0.01041667],
#          [ 0.296875  ],
#          [ 0.7890625 ],
#          ...,
#          [-0.14322917],
#          [ 0.11458333],
#          [ 0.76041667]],
#
#         [[ 0.29166667],
#          [ 0.52083333],
#          [ 0.70833333],
#          ...,
#          [-0.06770833],
#          [ 0.44270833],
#          [ 0.89583333]],
#
#         ...,
#
#         [[ 0.16666667],
#          [-0.3828125 ],
#          [-0.47395833],
#          ...,
#          [-0.63541667],
#          [-0.33333333],
#          [-0.17708333]],
#
#         [[ 0.09895833],
#          [-0.453125  ],
#          [-0.4609375 ],
#          ...,
#          [-0.63541667],
#          [-0.46875   ],
#          [-0.37239583]],
#
#         [[-0.1953125 ],
#          [-0.55208333],
#          [-0.44791667],
#          ...,
#          [-0.58854167],
#          [-0.51041667],
#          [-0.49739583]]],
#
#
#        [[[-0.7578125 ],
#          [-0.734375  ],
#          [-0.70572917],
#          ...,
#          [-0.48958333],
#          [-0.52083333],
#          [-0.52864583]],
#
#         [[-0.7734375 ],
#          [-0.76302083],
#          [-0.70833333],
#          ...,
#          [-0.52864583],
#          [-0.57552083],
#          [-0.5703125 ]],
#
#         [[-0.7421875 ],
#          [-0.7265625 ],
#          [-0.69270833],
#          ...,
#          [-0.60416667],
#          [-0.61197917],
#          [-0.57552083]],
#
#         ...,
#
#         [[-0.82291667],
#          [-0.81770833],
#          [-0.81510417],
#          ...,
#          [-0.67447917],
#          [-0.69010417],
#          [-0.72135417]],
#
#         [[-0.74479167],
#          [-0.7421875 ],
#          [-0.73958333],
#          ...,
#          [-0.65625   ],
#          [-0.6640625 ],
#          [-0.6796875 ]],
#
#         [[-0.6953125 ],
#          [-0.70572917],
#          [-0.70572917],
#          ...,
#          [-0.64583333],
#          [-0.64583333],
#          [-0.65625   ]]],
#
#
#        [[[-0.49739583],
#          [-0.49739583],
#          [-0.5       ],
#          ...,
#          [-0.5546875 ],
#          [-0.5625    ],
#          [-0.5546875 ]],
#
#         [[-0.49479167],
#          [-0.50260417],
#          [-0.50520833],
#          ...,
#          [-0.55208333],
#          [-0.55989583],
#          [-0.55989583]],
#
#         [[-0.4921875 ],
#          [-0.49739583],
#          [-0.50260417],
#          ...,
#          [-0.54947917],
#          [-0.55989583],
#          [-0.55989583]],
#
#         ...,
#
#         [[-0.45572917],
#          [-0.45833333],
#          [-0.44010417],
#          ...,
#          [-0.48177083],
#          [-0.49479167],
#          [-0.49739583]],
#
#         [[-0.46614583],
#          [-0.453125  ],
#          [-0.44270833],
#          ...,
#          [-0.4765625 ],
#          [-0.4921875 ],
#          [-0.49739583]],
#
#         [[-0.46354167],
#          [-0.45572917],
#          [-0.4453125 ],
#          ...,
#          [-0.47395833],
#          [-0.4921875 ],
#          [-0.50520833]]]])

# %%
i = random.randint(1, len(X_train_gray))
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# # 5: UNDERSTAND THE THEORY AND INTUITION BEHIND CONVOLUTIONAL NEURAL NETWORKS

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/FatmaElZahraaSamir/Traffic-Sign-Classification-Using-DL/master/imgs/4.png)

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/FatmaElZahraaSamir/Traffic-Sign-Classification-Using-DL/master/imgs/5.png)

# %% [markdown]
# # 6: BUILD DEEP CONVOLUTIONAL NEURAL NETWORK MODEL

# %%
from tensorflow.keras import datasets, layers, models
CNN = models.Sequential()

CNN.add(layers.Conv2D(6, (5,5), activation = 'relu', input_shape = (32,32,1)))
CNN.add(layers.AveragePooling2D())

CNN.add(layers.Dropout(0.2))  

CNN.add(layers.Conv2D(16, (5,5), activation = 'relu'))
CNN.add(layers.AveragePooling2D())

CNN.add(layers.Flatten())

CNN.add(layers.Dense(120, activation='relu'))
CNN.add(layers.Dense(84, activation = 'relu'))
CNN.add(layers.Dense(43, activation = 'softmax'))
CNN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                3655
# =================================================================
# Total params: 64,511
# Trainable params: 64,511
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 7: COMPILE AND TRAIN DEEP CNN MODEL

# %%
CNN.compile(optimizer = 'Adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
history = CNN.fit(X_train_gray_norm,
                 y_train,
                 batch_size = 500,
                 epochs = 60,
                 verbose = 1,
                 validation_data = (X_validation_gray_norm, y_validation))
# Out:
# Epoch 1/60
# 70/70 [==============================] - 16s 229ms/step - loss: 3.2364 - accuracy: 0.1565 - val_loss: 2.8631 - val_accuracy: 0.3023
# Epoch 2/60
# 70/70 [==============================] - 16s 230ms/step - loss: 2.0068 - accuracy: 0.4467 - val_loss: 1.5602 - val_accuracy: 0.5567
# Epoch 3/60
# 70/70 [==============================] - 16s 231ms/step - loss: 1.1883 - accuracy: 0.6532 - val_loss: 0.9965 - val_accuracy: 0.7052
# Epoch 4/60
# 70/70 [==============================] - 16s 234ms/step - loss: 0.8553 - accuracy: 0.7468 - val_loss: 0.7990 - val_accuracy: 0.7546
# Epoch 5/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.6944 - accuracy: 0.7972 - val_loss: 0.6875 - val_accuracy: 0.8007
# Epoch 6/60
# 70/70 [==============================] - 16s 231ms/step - loss: 0.5786 - accuracy: 0.8305 - val_loss: 0.5833 - val_accuracy: 0.8324
# Epoch 7/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.4898 - accuracy: 0.8607 - val_loss: 0.5677 - val_accuracy: 0.8401
# Epoch 8/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.4296 - accuracy: 0.8769 - val_loss: 0.5211 - val_accuracy: 0.8528
# Epoch 9/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.3821 - accuracy: 0.8920 - val_loss: 0.4956 - val_accuracy: 0.8596
# Epoch 10/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.3443 - accuracy: 0.9010 - val_loss: 0.4925 - val_accuracy: 0.8644
# Epoch 11/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.3117 - accuracy: 0.9106 - val_loss: 0.4420 - val_accuracy: 0.8859
# Epoch 12/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.2796 - accuracy: 0.9222 - val_loss: 0.4422 - val_accuracy: 0.8787
# Epoch 13/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.2598 - accuracy: 0.9271 - val_loss: 0.4245 - val_accuracy: 0.8832
# Epoch 14/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.2348 - accuracy: 0.9342 - val_loss: 0.3962 - val_accuracy: 0.8905
# Epoch 15/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.2207 - accuracy: 0.9394 - val_loss: 0.3980 - val_accuracy: 0.8930
# Epoch 16/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.2063 - accuracy: 0.9421 - val_loss: 0.3982 - val_accuracy: 0.8943
# Epoch 17/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.1919 - accuracy: 0.9460 - val_loss: 0.3854 - val_accuracy: 0.9023
# Epoch 18/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.1777 - accuracy: 0.9519 - val_loss: 0.3888 - val_accuracy: 0.8986
# Epoch 19/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.1698 - accuracy: 0.9517 - val_loss: 0.3985 - val_accuracy: 0.8980
# Epoch 20/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.1595 - accuracy: 0.9557 - val_loss: 0.3772 - val_accuracy: 0.9023
# Epoch 21/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.1504 - accuracy: 0.9584 - val_loss: 0.3557 - val_accuracy: 0.9061
# Epoch 22/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.1459 - accuracy: 0.9586 - val_loss: 0.3633 - val_accuracy: 0.9057
# Epoch 23/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.1293 - accuracy: 0.9644 - val_loss: 0.3670 - val_accuracy: 0.9079
# Epoch 24/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.1265 - accuracy: 0.9641 - val_loss: 0.3727 - val_accuracy: 0.9063
# Epoch 25/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.1207 - accuracy: 0.9655 - val_loss: 0.3852 - val_accuracy: 0.9061
# Epoch 26/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.1119 - accuracy: 0.9684 - val_loss: 0.3897 - val_accuracy: 0.9016
# Epoch 27/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.1109 - accuracy: 0.9694 - val_loss: 0.3797 - val_accuracy: 0.9052
# Epoch 28/60
# 70/70 [==============================] - 16s 234ms/step - loss: 0.1041 - accuracy: 0.9701 - val_loss: 0.3914 - val_accuracy: 0.9050
# Epoch 29/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.1018 - accuracy: 0.9701 - val_loss: 0.3658 - val_accuracy: 0.9082
# Epoch 30/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.0949 - accuracy: 0.9728 - val_loss: 0.3620 - val_accuracy: 0.9122
# Epoch 31/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.0881 - accuracy: 0.9742 - val_loss: 0.3762 - val_accuracy: 0.9145
# Epoch 32/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0897 - accuracy: 0.9733 - val_loss: 0.3676 - val_accuracy: 0.9120
# Epoch 33/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.0818 - accuracy: 0.9765 - val_loss: 0.3849 - val_accuracy: 0.9120
# Epoch 34/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0782 - accuracy: 0.9769 - val_loss: 0.3892 - val_accuracy: 0.9079
# Epoch 35/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.0758 - accuracy: 0.9777 - val_loss: 0.3779 - val_accuracy: 0.9143
# Epoch 36/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.0731 - accuracy: 0.9776 - val_loss: 0.3794 - val_accuracy: 0.9118
# Epoch 37/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0710 - accuracy: 0.9803 - val_loss: 0.3668 - val_accuracy: 0.9179
# Epoch 38/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0684 - accuracy: 0.9794 - val_loss: 0.3935 - val_accuracy: 0.9100
# Epoch 39/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0688 - accuracy: 0.9801 - val_loss: 0.3602 - val_accuracy: 0.9179
# Epoch 40/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0670 - accuracy: 0.9799 - val_loss: 0.3660 - val_accuracy: 0.9152
# Epoch 41/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.0633 - accuracy: 0.9809 - val_loss: 0.3580 - val_accuracy: 0.9156
# Epoch 42/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.0580 - accuracy: 0.9822 - val_loss: 0.3867 - val_accuracy: 0.9132
# Epoch 43/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0613 - accuracy: 0.9820 - val_loss: 0.3739 - val_accuracy: 0.9211
# Epoch 44/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0545 - accuracy: 0.9832 - val_loss: 0.3581 - val_accuracy: 0.9209
# Epoch 45/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0515 - accuracy: 0.9854 - val_loss: 0.3502 - val_accuracy: 0.9249
# Epoch 46/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0508 - accuracy: 0.9849 - val_loss: 0.3877 - val_accuracy: 0.9154
# Epoch 47/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0485 - accuracy: 0.9853 - val_loss: 0.3721 - val_accuracy: 0.9197
# Epoch 48/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0511 - accuracy: 0.9841 - val_loss: 0.3824 - val_accuracy: 0.9184
# Epoch 49/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0450 - accuracy: 0.9859 - val_loss: 0.3794 - val_accuracy: 0.9218
# Epoch 50/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0447 - accuracy: 0.9866 - val_loss: 0.3535 - val_accuracy: 0.9261
# Epoch 51/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0437 - accuracy: 0.9872 - val_loss: 0.4099 - val_accuracy: 0.9116
# Epoch 52/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0439 - accuracy: 0.9866 - val_loss: 0.3973 - val_accuracy: 0.9234
# Epoch 53/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0419 - accuracy: 0.9876 - val_loss: 0.3678 - val_accuracy: 0.9206
# Epoch 54/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0432 - accuracy: 0.9861 - val_loss: 0.3644 - val_accuracy: 0.9254
# Epoch 55/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.0389 - accuracy: 0.9886 - val_loss: 0.3691 - val_accuracy: 0.9342
# Epoch 56/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0397 - accuracy: 0.9884 - val_loss: 0.3751 - val_accuracy: 0.9215
# Epoch 57/60
# 70/70 [==============================] - 16s 232ms/step - loss: 0.0384 - accuracy: 0.9884 - val_loss: 0.4240 - val_accuracy: 0.9168
# Epoch 58/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.0439 - accuracy: 0.9855 - val_loss: 0.3803 - val_accuracy: 0.9218
# Epoch 59/60
# 70/70 [==============================] - 16s 233ms/step - loss: 0.0410 - accuracy: 0.9865 - val_loss: 0.4228 - val_accuracy: 0.9166
# Epoch 60/60
# 70/70 [==============================] - 16s 235ms/step - loss: 0.0390 - accuracy: 0.9878 - val_loss: 0.3397 - val_accuracy: 0.9331

# %% [markdown]
# # 8: ASSESS TRAINED CNN MODEL PERFORMANCE

# %%
score = CNN.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 395/395 [==============================] - 4s 11ms/step - loss: 0.6008 - accuracy: 0.9124
# Test Accuracy: 0.9123515486717224

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(accuracy))
plt.plot(epochs, loss, 'ro', label = 'Training Loss')
plt.plot(epochs, val_loss, 'r', label = 'Validation Loss')
plt.title('Training and Validation Loss')
# Out:
# Text(0.5, 1.0, 'Training and Validation Loss')

# %%
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'ro', label = 'Training accuracy')
plt.plot(epochs, val_accuracy, 'r', label = 'Validation accuracy')
plt.title('Training and Validation accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation accuracy')

# %%
predicted_classes = CNN.predict_classes(X_test_gray_norm)
y_true = y_test

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25, 25))
sns.heatmap(cm, annot = True)
# Out:
# WARNING:tensorflow:From <ipython-input-21-9c8a789d7b78>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
L = 5
W = 5

fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)

# %% [markdown]
# # APPENDIX

# %% [markdown]
# - In this case study, we want to classify images of traffic signs using deep Convolutional Neural Networks (CNNs).
# - The dataset consists of 43 different classes of images.
# - Classes are as listed below:
#   - 0 = Speed limit (20km/h)
#   - 1 = Speed limit (30km/h)
#   - 2 = Speed limit (50km/h)
#   - 3 = Speed limit (60km/h)
#   - 4 = Speed limit (70km/h)
#   - 5 = Speed limit (80km/h)
#   - 6 = End of speed limit (80km/h)
#   - 7 = Speed limit (100km/h)
#   - 8 = Speed limit (120km/h)
#   - 9 = No passing
#   - 10 = No passing for vehicles over 3.5 metric tons
#   - 11 = Right-of-way at the next intersection
#   - 12 = Priority road
#   - 13 = Yield
#   - 14 = Stop
#   - 15 = No vehicles
#   - 16 = Vehicles over 3.5 metric tons prohibited
#   - 17 = No entry
#   - 18 = General caution
#   - 19 = Dangerous curve to the left
#   - 20 = Dangerous curve to the right
#   - 21 = Double curve
#   - 22 = Bumpy road
#   - 23 = Slippery road
#   - 24 = Road narrows on the right
#   - 25 = Road work
#   - 26 = Traffic signals
#   - 27 = Pedestrians
#   - 28 = Children crossing
#   - 29 = Bicycles crossing
#   - 30 = Beware of ice/snow
#   - 31 = Wild animals crossing
#   - 32 = End of all speed and passing limits
#   - 33 = Turn right ahead
#   - 34 = Turn left ahead
#   - 35 = Ahead only
#   - 36 = Go straight or right
#   - 37 = Go straight or left
#   - 38 = Keep right
#   - 39 = Keep left
#   - 40 = Roundabout mandatory
#   - 41 = End of no passing
#   - 42 = End of no passing by vehicles over 3.5 metric tons
